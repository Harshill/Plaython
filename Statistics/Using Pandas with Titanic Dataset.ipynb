# %%
import pandas as pd
import numpy as np

data = pd.read_csv('D:/Library/Documents/Kaggle/train.csv')
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
# PassengerId    891 non-null int64
# Survived       891 non-null int64
# Pclass         891 non-null int64
# Name           891 non-null object
# Sex            891 non-null object
# Age            714 non-null float64
# SibSp          891 non-null int64
# Parch          891 non-null int64
# Ticket         891 non-null object
# Fare           891 non-null float64
# Cabin          204 non-null object
# Embarked       889 non-null object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.6+ KB

# %%
data.head(3)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S

# %%
data.iloc[0:4,0:5]             #gives us the rows and columns we want
data.sort_values(by = 'Survived').iloc[0:4,0:5]
# Out:
#      PassengerId  Survived  Pclass                     Name   Sex
# 0              1         0       3  Braund, Mr. Owen Harris  male
# 519          520         0       3      Pavlovic, Mr. Stefo  male
# 521          522         0       3          Vovk, Mr. Janko  male
# 522          523         0       3       Lahoud, Mr. Sarkis  male

# %%
data.groupby('Sex').mean()
# Out:
#         PassengerId  Survived    Pclass        Age     SibSp     Parch  \
# Sex
# female   431.028662  0.742038  2.159236  27.915709  0.694268  0.649682
# male     454.147314  0.188908  2.389948  30.726645  0.429809  0.235702
#
#              Fare
# Sex
# female  44.479818
# male    25.523893

# %%
data[data.Age < 18].mean()
# Out:
# PassengerId    429.212389
# Survived         0.539823
# Pclass           2.584071
# Age              9.041327
# SibSp            1.460177
# Parch            1.053097
# Fare            31.220798
# dtype: float64

# %%
data.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
# adding a column
data['Gender'] = data['Sex'].map( lambda x: x[0].upper() )
data.head(5)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked Gender
# 0      0         A/5 21171   7.2500   NaN        S      M
# 1      0          PC 17599  71.2833   C85        C      F
# 2      0  STON/O2. 3101282   7.9250   NaN        S      F
# 3      0            113803  53.1000  C123        S      F
# ...

# %%
data['Gender'] = data['Sex'].map( {'female': 0, 'male': 1} ).astype(int)
data['S'] = data['Survived'].map( {0: 'N', 1: 'Y'} )
data.head(5)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked  Gender  S
# 0      0         A/5 21171   7.2500   NaN        S       1  N
# 1      0          PC 17599  71.2833   C85        C       0  Y
# 2      0  STON/O2. 3101282   7.9250   NaN        S       0  Y
# 3      0            113803  53.1000  C123        S       0  Y
# ...

# %%
males = data[data['Sex'] == 'male'][['Sex', 'Pclass', 'Age', 'Survived', 'S']]
countm = males.groupby('S').count()
# Out:
#    Sex  Pclass  Age  Survived
# S
# N  468     468  360       468
# Y  109     109   93       109

# %%
females = data[data['Sex'] == 'female'][['Sex', 'Pclass', 'Age', 'Survived', 'S']]
countf = females.groupby('S').count()
countf
# Out:
#    Sex  Pclass  Age  Survived
# S
# N   81      81   64        81
# Y  233     233  197       233
